# %%
import json
import sqlite3
from shapely.geometry import shape, MultiPolygon
from shapely.wkb import dumps as wkb_dumps
from shapely.validation import explain_validity

# 1. 建立 SQLite 資料庫並啟用空間擴展
def create_spatial_database(db_path):
    conn = sqlite3.connect(db_path)
    conn.enable_load_extension(True)
    conn.execute("SELECT load_extension('mod_spatialite')")
    conn.execute("SELECT InitSpatialMetaData(1)")
    
    conn.execute('''CREATE TABLE IF NOT EXISTS site_effects
                 (town_name TEXT PRIMARY KEY, site_value REAL)''')
    
    conn.execute("""
        CREATE TABLE IF NOT EXISTS town_boundaries (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            name TEXT
        )
    """)
    conn.execute("""
        SELECT AddGeometryColumn('town_boundaries', 'geometry', 4326, 'MULTIPOLYGON', 'XY')
    """)
    return conn

# 2. 將 GeoJSON 轉換並插入 SQLite
def geojson_to_sqlite(geojson_path, db_path):
    with open(geojson_path, 'r', encoding='utf-8') as f:
        geojson_data = json.load(f)

    conn = create_spatial_database(db_path)
    cursor = conn.cursor()

    for feature in geojson_data['features']:
        id = feature.get('id', '')
        props = feature.get('properties', {})
        county_name = props.get('COUNTYNAME', 'unnamed')
        town_name = props.get('TOWNNAME', 'unnamed')
        name = county_name + town_name

        # 轉換幾何
        geom = shape(feature['geometry'])
        if geom.geom_type == 'Polygon':
            geom = MultiPolygon([geom])
        elif geom.geom_type != 'MultiPolygon':
            print(f"跳過不支持的幾何類型: {geom.geom_type}")
            continue

        if not geom.is_valid:
            print(f"修復前: {name}, 類型 = {geom.geom_type}, 有效性 = {geom.is_valid}, 原因 = {explain_validity(geom)}")
            geom = geom.buffer(0)
            print(f"修復後: {name}, 類型 = {geom.geom_type}, 有效性 = {geom.is_valid}")
        if geom.is_empty or not geom.is_valid:
            print(f"跳過無法修復的幾何: {name}, 原因: {explain_validity(geom)}")
            continue
        if geom.geom_type != 'MultiPolygon':
            print(f"類型不符: {name}, 修復後類型 = {geom.geom_type}")
            # 嘗試轉換回 MultiPolygon
            if geom.geom_type == 'Polygon':
                geom = MultiPolygon([geom])
            else:
                print(f"跳過不支持的修復後類型: {geom.geom_type} ({name})")
                continue

        wkb_geom = wkb_dumps(geom)

        cursor.execute("""
            INSERT INTO town_boundaries (id, name, geometry)
            VALUES (?, ?, GeomFromWKB(?, 4326))
        """, (id, name, wkb_geom))

    conn.commit()
    cursor.execute("SELECT CreateSpatialIndex('town_boundaries', 'geometry')")
    conn.commit()
    conn.close()
    print(f"成功將 GeoJSON 轉換到 {db_path}")

# 3. 時空查詢函數
def coords_to_town(db_path, lat, lon):
    conn = sqlite3.connect(db_path)
    conn.enable_load_extension(True)
    conn.execute("SELECT load_extension('mod_spatialite')")
    cursor = conn.cursor()

    query = """
        SELECT name
        FROM town_boundaries
        WHERE ST_Contains(geometry, MakePoint(?, ?, 4326))
    """
    cursor.execute(query, (lon, lat))
    result = cursor.fetchone()
    
    conn.close()
    return result[0] if result else None

if __name__ == "__main__":
    geojson_file = "taiwan_town.geojson"
    sqlite_db = "geo_seismic_data.db"

    #geojson_to_sqlite(geojson_file, sqlite_db)

    latitude = 120.354952
    longitude = 23.760542
    nearby_town = coords_to_town(sqlite_db, latitude, longitude)
    print(f"附近鄉鎮: {nearby_town}")
# Out:
# 修復前: 臺東縣成功鎮, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.4097 23.2138]
# 修復後: 臺東縣成功鎮, 類型 = Polygon, 有效性 = True
# 類型不符: 臺東縣成功鎮, 修復後類型 = Polygon
# 修復前: 彰化縣社頭鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[120.6284 23.9314]
# 修復後: 彰化縣社頭鄉, 類型 = Polygon, 有效性 = True
# 類型不符: 彰化縣社頭鄉, 修復後類型 = Polygon
# 修復前: 嘉義縣番路鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[120.4953 23.4529]
# 修復後: 嘉義縣番路鄉, 類型 = Polygon, 有效性 = True
# 類型不符: 嘉義縣番路鄉, 修復後類型 = Polygon
# 修復前: 宜蘭縣宜蘭市, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.776 24.7147]
# 修復後: 宜蘭縣宜蘭市, 類型 = Polygon, 有效性 = True
# 類型不符: 宜蘭縣宜蘭市, 修復後類型 = Polygon
# 修復前: 連江縣南竿鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[119.9646 26.1444]
# 修復後: 連江縣南竿鄉, 類型 = MultiPolygon, 有效性 = True
# 修復前: 連江縣莒光鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[119.9745 25.9748]
# 修復後: 連江縣莒光鄉, 類型 = MultiPolygon, 有效性 = True
# 修復前: 宜蘭縣羅東鎮, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.8022 24.6704]
# 修復後: 宜蘭縣羅東鎮, 類型 = Polygon, 有效性 = True
# 類型不符: 宜蘭縣羅東鎮, 修復後類型 = Polygon
# 修復前: 宜蘭縣員山鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.6229 24.6816]
# 修復後: 宜蘭縣員山鄉, 類型 = Polygon, 有效性 = True
# 類型不符: 宜蘭縣員山鄉, 修復後類型 = Polygon
# 修復前: 新竹縣竹東鎮, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.0696 24.7309]
# 修復後: 新竹縣竹東鎮, 類型 = Polygon, 有效性 = True
# 類型不符: 新竹縣竹東鎮, 修復後類型 = Polygon
# 修復前: 澎湖縣湖西鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[119.6062 23.5852]
# 修復後: 澎湖縣湖西鄉, 類型 = MultiPolygon, 有效性 = True
# 修復前: 嘉義縣大林鎮, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[120.5333 23.5968]
# 修復後: 嘉義縣大林鎮, 類型 = Polygon, 有效性 = True
# 類型不符: 嘉義縣大林鎮, 修復後類型 = Polygon
# 修復前: 嘉義縣梅山鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[120.5147 23.5431]
# 修復後: 嘉義縣梅山鄉, 類型 = Polygon, 有效性 = True
# 類型不符: 嘉義縣梅山鄉, 修復後類型 = Polygon
# 修復前: 屏東縣萬巒鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Self-intersection[120.6336 22.5248]
# 修復後: 屏東縣萬巒鄉, 類型 = Polygon, 有效性 = True
# 類型不符: 屏東縣萬巒鄉, 修復後類型 = Polygon
# 修復前: 屏東縣獅子鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[120.736 22.1183]
# 修復後: 屏東縣獅子鄉, 類型 = Polygon, 有效性 = True
# 類型不符: 屏東縣獅子鄉, 修復後類型 = Polygon
# 修復前: 澎湖縣白沙鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[119.6112 23.7799]
# 修復後: 澎湖縣白沙鄉, 類型 = MultiPolygon, 有效性 = True
# 修復前: 澎湖縣望安鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[119.3186 23.3249]
# 修復後: 澎湖縣望安鄉, 類型 = MultiPolygon, 有效性 = True
# 修復前: 澎湖縣七美鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[119.4383 23.2015]
# 修復後: 澎湖縣七美鄉, 類型 = Polygon, 有效性 = True
# 類型不符: 澎湖縣七美鄉, 修復後類型 = Polygon
# 修復前: 宜蘭縣頭城鎮, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[124.5564 25.9218]
# 修復後: 宜蘭縣頭城鎮, 類型 = MultiPolygon, 有效性 = True
# 修復前: 高雄市鳥松區, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[120.3778 22.6378]
# 修復後: 高雄市鳥松區, 類型 = Polygon, 有效性 = True
# 類型不符: 高雄市鳥松區, 修復後類型 = Polygon
# 修復前: 高雄市杉林區, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[120.5166 22.9114]
# 修復後: 高雄市杉林區, 類型 = Polygon, 有效性 = True
# 類型不符: 高雄市杉林區, 修復後類型 = Polygon
# 修復前: 新北市平溪區, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.7758 24.9855]
# 修復後: 新北市平溪區, 類型 = Polygon, 有效性 = True
# 類型不符: 新北市平溪區, 修復後類型 = Polygon
# 修復前: 臺南市北區, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[120.233 22.9985]
# 修復後: 臺南市北區, 類型 = Polygon, 有效性 = True
# 類型不符: 臺南市北區, 修復後類型 = Polygon
# 修復前: 花蓮縣玉里鎮, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.4471 23.4438]
# 修復後: 花蓮縣玉里鎮, 類型 = Polygon, 有效性 = True
# 類型不符: 花蓮縣玉里鎮, 修復後類型 = Polygon
# 修復前: 新北市泰山區, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.4031 25.0455]
# 修復後: 新北市泰山區, 類型 = Polygon, 有效性 = True
# 類型不符: 新北市泰山區, 修復後類型 = Polygon
# 修復前: 新北市三重區, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.471 25.0734]
# 修復後: 新北市三重區, 類型 = Polygon, 有效性 = True
# 類型不符: 新北市三重區, 修復後類型 = Polygon
# 修復前: 新北市萬里區, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.5899 25.1637]
# 修復後: 新北市萬里區, 類型 = Polygon, 有效性 = True
# 類型不符: 新北市萬里區, 修復後類型 = Polygon
# 修復前: 金門縣烈嶼鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[118.2628 24.4233]
# 修復後: 金門縣烈嶼鄉, 類型 = Polygon, 有效性 = True
# 類型不符: 金門縣烈嶼鄉, 修復後類型 = Polygon
# 修復前: 高雄市旗津區, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[116.7148 20.7026]
# 修復後: 高雄市旗津區, 類型 = MultiPolygon, 有效性 = True
# 修復前: 金門縣金城鎮, 類型 = MultiPolygon, 有效性 = False, 原因 = Self-intersection[118.32 24.3858]
# 修復後: 金門縣金城鎮, 類型 = Polygon, 有效性 = True
# 類型不符: 金門縣金城鎮, 修復後類型 = Polygon
# 修復前: 金門縣金湖鎮, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[118.4688 24.4403]
# 修復後: 金門縣金湖鎮, 類型 = Polygon, 有效性 = True
# 類型不符: 金門縣金湖鎮, 修復後類型 = Polygon
# 修復前: 花蓮縣萬榮鄉, 類型 = MultiPolygon, 有效性 = False, 原因 = Ring Self-intersection[121.3252 23.4673]
# 修復後: 花蓮縣萬榮鄉, 類型 = Polygon, 有效性 = True
# 類型不符: 花蓮縣萬榮鄉, 修復後類型 = Polygon
# 成功將 GeoJSON 轉換到 geo_seismic_data.db
